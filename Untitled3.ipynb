# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('online_learning_platform.csv')

# %%
df.head()
# Out:
#    UserID UserName  Age  Gender         Region  SignupDate  CourseID  \
# 0       1  User001   56   Other           Asia  2022-02-21      4657
# 1       2  User002   38   Other         Africa  2022-06-28      1520
# 2       3  User003   41   Other         Africa  2022-02-24      9928
# 3       4  User004   19  Female           Asia  2022-11-23      5552
# 4       5  User005   38    Male  South America  2022-07-18      5333
#
#                CourseName   Category  CoursePrice PurchaseDate  DurationHours  \
# 0            UI/UX Design     Design       161.34   2022-08-14            8.2
# 1      Business Analytics   Business        39.64   2022-08-27            7.1
# 2        Startup Strategy   Business        73.40   2022-07-25            6.6
# 3  Social Media Marketing  Marketing       147.18   2022-12-20           37.6
# 4        Photoshop Basics     Design       127.32   2022-12-03           24.9
#
#    Rating  IsCertificateIssued PaymentMethod  IsActiveSubscription
# ...

# %%
df.tail()
# Out:
#      UserID UserName  Age  Gender         Region  SignupDate  CourseID  \
# 195     196  User196   31   Other  North America  2024-12-28      3762
# 196     197  User197   42    Male           Asia  2022-06-16      5336
# 197     198  User198   49   Other           Asia  2024-10-16      5949
# 198     199  User199   32  Female           Asia  2022-05-03      7809
# 199     200  User200   19   Other         Europe  2023-10-03      6658
#
#                 CourseName         Category  CoursePrice PurchaseDate  \
# 195   Deep Learning Basics     Data Science       109.38   2025-05-22
# 196   Deep Learning Basics     Data Science       139.77   2022-11-22
# 197     Business Analytics         Business        97.91   2025-01-01
# 198  JavaScript Essentials  Web Development       119.72   2022-07-30
# 199    Figma for Designers           Design       113.28   2024-02-12
#
#      DurationHours  Rating  IsCertificateIssued PaymentMethod  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   UserID                200 non-null    int64
#  1   UserName              200 non-null    object
#  2   Age                   200 non-null    int64
#  3   Gender                200 non-null    object
#  4   Region                200 non-null    object
#  5   SignupDate            200 non-null    object
#  6   CourseID              200 non-null    int64
#  7   CourseName            200 non-null    object
#  8   Category              200 non-null    object
#  9   CoursePrice           200 non-null    float64
#  10  PurchaseDate          200 non-null    object
#  11  DurationHours         200 non-null    float64
#  12  Rating                200 non-null    float64
#  13  IsCertificateIssued   200 non-null    bool
#  14  PaymentMethod         200 non-null    object
# ...

# %%
df.describe()
# Out:
#            UserID         Age    CourseID  CoursePrice  DurationHours  \
# count  200.000000  200.000000   200.00000   200.000000     200.000000
# mean   100.500000   38.350000  5440.08000   107.868400      21.294500
# std     57.879185   11.905723  2473.00017    55.759057      10.940966
# min      1.000000   18.000000  1018.00000    12.060000       1.300000
# 25%     50.750000   28.000000  3457.75000    60.310000      12.325000
# 50%    100.500000   38.000000  5401.50000   111.040000      21.750000
# 75%    150.250000   49.000000  7294.25000   156.045000      30.125000
# max    200.000000   59.000000  9984.00000   199.290000      39.800000
#
#            Rating
# count  200.000000
# mean     2.836000
# std      1.213659
# min      1.000000
# 25%      1.800000
# 50%      2.700000
# 75%      3.900000
# max      5.000000

# %%
df.columns
# Out:
# Index(['UserID', 'UserName', 'Age', 'Gender', 'Region', 'SignupDate',
#        'CourseID', 'CourseName', 'Category', 'CoursePrice', 'PurchaseDate',
#        'DurationHours', 'Rating', 'IsCertificateIssued', 'PaymentMethod',
#        'IsActiveSubscription'],
#       dtype='object')

# %%
df.dtypes
# Out:
# UserID                    int64
# UserName                 object
# Age                       int64
# Gender                   object
# Region                   object
# SignupDate               object
# CourseID                  int64
# CourseName               object
# Category                 object
# CoursePrice             float64
# PurchaseDate             object
# DurationHours           float64
# Rating                  float64
# IsCertificateIssued        bool
# PaymentMethod            object
# IsActiveSubscription       bool
# dtype: object

# %%
df.head()
# Out:
#    UserID UserName  Age  Gender         Region  SignupDate  CourseID  \
# 0       1  User001   56   Other           Asia  2022-02-21      4657
# 1       2  User002   38   Other         Africa  2022-06-28      1520
# 2       3  User003   41   Other         Africa  2022-02-24      9928
# 3       4  User004   19  Female           Asia  2022-11-23      5552
# 4       5  User005   38    Male  South America  2022-07-18      5333
#
#                CourseName   Category  CoursePrice PurchaseDate  DurationHours  \
# 0            UI/UX Design     Design       161.34   2022-08-14            8.2
# 1      Business Analytics   Business        39.64   2022-08-27            7.1
# 2        Startup Strategy   Business        73.40   2022-07-25            6.6
# 3  Social Media Marketing  Marketing       147.18   2022-12-20           37.6
# 4        Photoshop Basics     Design       127.32   2022-12-03           24.9
#
#    Rating  IsCertificateIssued PaymentMethod  IsActiveSubscription
# ...

# %%
df['Region'].unique()
# Out:
# array(['Asia', 'Africa', 'South America', 'Europe', 'North America'],
#       dtype=object)

# %%
df['Region'].value_counts()
# Out:
# Region
# South America    49
# North America    44
# Asia             43
# Africa           33
# Europe           31
# Name: count, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Other     74
# Female    65
# Male      61
# Name: count, dtype: int64

# %%
df['CourseName'].value_counts()
# Out:
# CourseName
# Social Media Marketing     20
# UI/UX Design               18
# Business Analytics         18
# SEO Fundamentals           18
# Deep Learning Basics       16
# HTML & CSS                 16
# Email Marketing            15
# Startup Strategy           12
# Finance for Non-Finance    12
# JavaScript Essentials      11
# Figma for Designers        11
# Python for Data Science    10
# React for Beginners        10
# Machine Learning 101        8
# Photoshop Basics            5
# Name: count, dtype: int64

# %%
df_Asia = df[df['Region']=='Asia']

# %%
df_Asia.shape
# Out:
# (43, 16)

# %%
df_Asia['CourseName'].value_counts()
# Out:
# CourseName
# Business Analytics         6
# UI/UX Design               5
# HTML & CSS                 5
# Figma for Designers        4
# Social Media Marketing     3
# Email Marketing            3
# Startup Strategy           3
# SEO Fundamentals           3
# JavaScript Essentials      3
# Finance for Non-Finance    2
# React for Beginners        2
# Deep Learning Basics       2
# Python for Data Science    1
# Machine Learning 101       1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
y = df['CourseName'].value_counts().values
x = df['CourseName'].value_counts().index

# %%
plt.bar(x,y)
plt.xticks(rotation = 90)
plt.show()

# %%
df.groupby('Region')['CoursePrice'].sum()
# Out:
# Region
# Africa           3511.27
# Asia             4515.02
# Europe           3522.15
# North America    4924.90
# South America    5100.34
# Name: CoursePrice, dtype: float64

# %%
df.groupby("Region")['CoursePrice'].mean()
# Out:
# Region
# Africa           106.402121
# Asia             105.000465
# Europe           113.617742
# North America    111.929545
# South America    104.088571
# Name: CoursePrice, dtype: float64

# %%
df.groupby("PaymentMethod")['CoursePrice'].sum()
# Out:
# PaymentMethod
# Credit Card    6713.49
# PayPal         7122.78
# UPI            7737.41
# Name: CoursePrice, dtype: float64

# %%
df.groupby("CourseName")['CoursePrice'].sum()
# Out:
# CourseName
# Business Analytics         1687.79
# Deep Learning Basics       1666.87
# Email Marketing            1937.15
# Figma for Designers        1056.67
# Finance for Non-Finance    1240.98
# HTML & CSS                 1763.54
# JavaScript Essentials      1263.45
# Machine Learning 101        889.44
# Photoshop Basics            515.38
# Python for Data Science    1246.28
# React for Beginners         957.58
# SEO Fundamentals           2353.01
# Social Media Marketing     2281.67
# Startup Strategy            930.37
# UI/UX Design               1783.50
# Name: CoursePrice, dtype: float64

# %%
x = df.groupby("CourseName")['CoursePrice'].sum().index
y = df.groupby("CourseName")['CoursePrice'].sum().values
x,y
# Out:
# (Index(['Business Analytics', 'Deep Learning Basics', 'Email Marketing',
#         'Figma for Designers', 'Finance for Non-Finance', 'HTML & CSS',
#         'JavaScript Essentials', 'Machine Learning 101', 'Photoshop Basics',
#         'Python for Data Science', 'React for Beginners', 'SEO Fundamentals',
#         'Social Media Marketing', 'Startup Strategy', 'UI/UX Design'],
#        dtype='object', name='CourseName'),
#  array([1687.79, 1666.87, 1937.15, 1056.67, 1240.98, 1763.54, 1263.45,
#          889.44,  515.38, 1246.28,  957.58, 2353.01, 2281.67,  930.37,
#         1783.5 ]))

# %%
plt.plot(x,y)
plt.xticks(rotation = 90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.sort_values(by = ['CoursePrice'], ascending = False).head(3)
# Out:
#      UserID UserName  Age  Gender         Region  SignupDate  CourseID  \
# 50       51  User051   19    Male  North America  2023-04-06      1400
# 126     127  User127   38    Male  South America  2024-12-13      2041
# 137     138  User138   49  Female  North America  2023-12-20      3347
#
#                   CourseName         Category  CoursePrice PurchaseDate  \
# 50                HTML & CSS  Web Development       199.29   2023-09-10
# 126     Deep Learning Basics     Data Science       198.66   2025-04-24
# 137  Python for Data Science     Data Science       197.20   2024-05-31
#
#      DurationHours  Rating  IsCertificateIssued PaymentMethod  \
# 50            38.7     3.2                 True   Credit Card
# 126            3.9     3.2                False           UPI
# 137           15.7     4.0                False   Credit Card
#
#      IsActiveSubscription
# 50                  False
# 126                 False
# 137                  True

# %%
df.groupby('Region')['CoursePrice'].sum().sort_values(ascending = False).head(3)
# Out:
# Region
# South America    5100.34
# North America    4924.90
# Asia             4515.02
# Name: CoursePrice, dtype: float64
